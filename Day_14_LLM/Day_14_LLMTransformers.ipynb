# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator("The hero enters the ancient forest and discovers", max_new_tokens=30)
print(result[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers that the dragon is an animal, and that he is the one who defeated the dragon. The heroes find that the dragon is the one who caused the

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “I have chest pain and shortness of breath”
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "I have chest pain and shortness of breath"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands'}]
# [{'generated_text': 'The future of Artificial Intelligence and artificial intelligence is being developed, where one can imagine that every day, people will be able to build and learn from artificial intelligence, because these are the very things that will help make it easier for people to make intelligent decisions. I don\'t think we have the tools to make that happen yet. However, one thing is clear. Artificial intelligence is becoming more and more complex and complex. It is becoming better at its job of solving problems that human beings face all the time. It is an incredibly complex problem that we will likely never solve.\n\n"The best we can do at the moment is to continue innovating and growing as an entity. We don\'t have the tools for that. The best we can do is to continue innovating and growing as an entity. We don\'t have the tools to make that happen yet. However, one thing is clear. Artificial intelligence is becoming more and more complex and complex. It is becoming better at its job of solving problems that human beings face all the time. It is an incredibly complex problem that we will likely never solve.\n\nWhile we should not be too surprised when Apple\'s new CEO, Tim Cook, says he will not be returning anytime soon, I think it\'s time to see what happens when we do'}]

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_new_tokens=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: Hii
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# HiiIIKmR6wIj8Vx2XVc6mV8a0IwJ8eX5X2F2IjkX3fR9oI9m3YhIyg

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the world in a big way.\n\nThis article is part of the TechRepublic series, "The Future of Artificial Intelligence."\n\nIn this article, we will analyze the current state of the technology and its challenges to life. We will also take a look at how it may be used to create artificial intelligence (AI) applications.\n\nIn order to build a computer that is in the best position to help us understand the world around us and find ways to solve problems, it is necessary to have a complete understanding of the world around us. This is why we often see the world around us as a\'sphere of information\', a place of knowledge, of solutions and solutions. This is also why we tend to think of the world around us as a\'sphere of knowledge\', where we are able to use our knowledge of the world to solve problems.\n\nThe current state of AI\n\nSo far, AI technology has been designed to be able to solve a series of problems. It is the world\'s most advanced system, capable of solving most major problems in the world. It is even being used to create real-life situations.\n\nBut there are many other problems, for which it is possible to use artificial intelligence to solve them. In'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform a world of our own. We are not just humans but also machines in a new way.\n\n\n\n\n\n\n\n\n\nIn the past in computers, machines were all thought to be machines. In this way, machines were machines in a world where humans could create intelligent machines.\nIn this way, machines were machines in a world where humans could create intelligent machines.\nIn this way, machines were machines in a world where humans could create intelligent machines.\nIn this way, humans could create intelligent machines. In this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines. In this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans can create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create intelligent machines.\nIn this way, humans could create'}]
