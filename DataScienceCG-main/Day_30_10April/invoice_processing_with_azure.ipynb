# %%
#  Scenario: Automating Invoice Processing with Azure Form Recognizer
# Context
# You’re a data engineer at an e‑commerce company. Your finance team receives
#  hundreds of invoices in PNG format from vendors. Manually typing invoice
#   details into the ERP system is slow and error‑prone. You decide to use
# Azure
#   Form Recognizer’s prebuilt invoice model to automate extraction.


import requests, time, os
from dotenv import load_dotenv
load_dotenv()

endpoint = os.environ['DOC_INTELLIGENCE_ENDPOINT']
key = os.environ['DOC_INTELLIGENCE_KEY']

url = endpoint + "/formrecognizer/documentModels/prebuilt-invoice:analyze?api-version=2023-07-31"

headers = {
    "Ocp-Apim-Subscription-Key": key,
    "Content-Type": "image/png"   # <-- important for PNG
}

with open("payment1.png", "rb") as f:
    data = f.read()

response = requests.post(url, headers=headers, data=data)

print(f"Status Code: {response.status_code}")

if response.status_code == 202:
    result_url = response.headers["operation-location"]
    time.sleep(3)
    result = requests.get(result_url, headers={"Ocp-Apim-Subscription-Key": key})
    result_json = result.json()
# Out:
# Status Code: 202

# %%
result_json
for word in result_json['analyzeResult']['pages'][0]['words']:
    print(word["content"])
# Out:
# RECEIPT
# LOGO
# East
# Repair
# Inc.
# 1912
# Harvest
# Lane
# New
# York,
# NY
# 12210
# BILL
# TO
# SHIP
# TO
# RECEIPT
# #
# US-001
# John
# Smith
# John
# Smith
# RECEIPT
# DATE
# 2
# Court
# Square
# 3787
# Pineview
# Drive
# 11/02/2019
# New
# York,
# NY
# 12210
# Cambridge,
# MA
# 12210
# P.O.#
# 2312/2019
# DUE
# DATE
# 26/02/2019
# QTY
# DESCRIPTION
# UNIT
# PRICE
# AMOUNT
# 1
# Front
# and
# rear
# brake
# cables
# 100.00
# 100.00
# 2
# New
# set
# of
# pedal
# arms
# 15.00
# 30.00
# 3
# Labor
# 3hrs
# 5.00
# 15.00
# Subtotal
# 145.00
# Sales
# Tax
# 6.25%
# 9.06
# TOTAL
# $154.06
# John
# Smith
# TERMS
# &
# CONDITIONS
# Thank
# you
# Payment
# is
# due
# within
# 15
# days
# Please
# make
# checks
# payable
# to:
# East
# Repair
# Inc.

# %%
import requests

endpoint = os.environ['DOC_INTELLIGENCE_ENDPOINT']
key = os.environ['DOC_INTELLIGENCE_KEY']

url = endpoint + "/formrecognizer/documentModels/prebuilt-invoice:analyze?api-version=2023-07-31"

headers = {
    "Ocp-Apim-Subscription-Key": key,
    "Content-Type": "application/json"
}

# Direct file link (must be publicly accessible)
data = {
    "urlSource": "https://filesamples.com/samples/document/pdf/sample1.pdf"
}

response = requests.post(url, headers=headers, json=data)

print("Status Code:", response.status_code)
print("Operation Location:", response.headers.get("operation-location"))
# Out:
# Status Code: 202
# Operation Location: https://document-intelligence-first.cognitiveservices.azure.com/formrecognizer/documentModels/prebuilt-invoice/analyzeResults/ef378aff-fa26-421a-956a-3731ec1308ac?api-version=2023-07-31
